# %% [markdown]
# PHASE 0 - IMPORT DATASET

# %%
# Import basic libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import  ModelCheckpoint
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Read the dataset
DataFrame = pd.read_csv('data.csv')

# %% [markdown]
# PHASE 1 - PREPROCESSING

# %%
#Drop useles columns
DataFrame = DataFrame.drop(['Unnamed: 6','Unnamed: 7', 'Unnamed: 8'], axis=1)

# %%
DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651185 entries, 0 to 651184
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   from_node  651185 non-null  int64
#  1   to_node    651185 non-null  int64
#  2   Ptran      651184 non-null  float64
#  3   Prec       651185 non-null  float64
#  4   RSSI       651185 non-null  float64
#  5   PDR        651185 non-null  float64
# dtypes: float64(4), int64(2)
# memory usage: 29.8 MB

# %%
# Limit the decimal points to 4
DataFrame['Prec'] = DataFrame['Prec'].round(decimals=4)
DataFrame['RSSI'] = DataFrame['RSSI'].round(decimals=4)

# %%
#Drop NaN rows if they exist
DataFrame = DataFrame.dropna()

# %%
#Drop rows with 0 in PDR as they work as outliers
DataFrame.drop(DataFrame[DataFrame['PDR'] == 0].index, inplace = True)
#Drop rows wih PDR over 1 as they work as outliers
DataFrame.drop(DataFrame[DataFrame['PDR'] > 1].index, inplace = True)

# %%
# Forward fill PDR for each link
DataFrame['PDR'] = DataFrame.groupby(['from_node', 'to_node'])['PDR'].ffill().fillna(0)

# %%
# Reindex the dataframe after deletion of rows
DataFrame.reset_index(drop=True, inplace=True)

# %%
DataFrame
# Out:
#       from_node  to_node  Ptran     Prec       RSSI       PDR
# 0             3        1   -1.0 -67.9637 -1200.2879  1.000000
# 1             1        3   -1.0 -67.9637  -895.0007  1.000000
# 2             3        1   -1.0 -67.9637 -1200.2879  1.000000
# 3             4        3   -1.0 -88.5280  -874.4364  0.999432
# 4             8        3   -1.0 -66.3056  -992.4616  1.000000
# ...         ...      ...    ...      ...        ...       ...
# 6087          5        9    7.0 -79.0754  -647.7996  1.000000
# 6088          1        5    7.0 -80.4640 -1029.7147  1.000000
# 6089          9        6    7.0 -79.8773 -1193.2674  1.000000
# 6090          2        7    7.0 -81.8447 -1045.0763  0.999999
# 6091          5        1    7.0 -80.4640 -1028.1080  1.000000
#
# [6092 rows x 6 columns]

# %%
#Drop the from_node and to_node as they are not needed for our model
DataFrame = DataFrame.drop(['from_node','to_node'], axis=1)

# %%
#Print the final data
DataFrame
# Out:
#       Ptran     Prec       RSSI       PDR
# 0      -1.0 -67.9637 -1200.2879  1.000000
# 1      -1.0 -67.9637  -895.0007  1.000000
# 2      -1.0 -67.9637 -1200.2879  1.000000
# 3      -1.0 -88.5280  -874.4364  0.999432
# 4      -1.0 -66.3056  -992.4616  1.000000
# ...     ...      ...        ...       ...
# 6087    7.0 -79.0754  -647.7996  1.000000
# 6088    7.0 -80.4640 -1029.7147  1.000000
# 6089    7.0 -79.8773 -1193.2674  1.000000
# 6090    7.0 -81.8447 -1045.0763  0.999999
# 6091    7.0 -80.4640 -1028.1080  1.000000
#
# [6092 rows x 4 columns]

# %% [markdown]
# PHASE 2 - DATA VISUALIZATION

# %%
# Show the correlation of data using Heatmap
sns.heatmap(DataFrame.corr(), annot=True, cmap="YlGnBu")
plt.show()
#Based in the plot bellow, we can conclude that no varriable is correlated among other varriables

# %%
# Visualize 'PDR' column using histogram
plt.hist(DataFrame['PDR'])
plt.xlabel('PDRs Achieved')
plt.ylabel('Number of observations')
plt.show()

# %%
# Visualize 'RSSI' column using histogram
plt.hist(DataFrame['RSSI'])
plt.xlabel('RSSIs Existed')
plt.ylabel('Number of observations')
plt.show()

# %%
# Visualize 'Prec' column using histogram
plt.hist(DataFrame['Prec'])
plt.xlabel('Precs Existed')
plt.ylabel('Number of observations')
plt.show()

# %%
# Visualize 'Ptrab' column using histogram
plt.hist(DataFrame['Ptran'])
plt.xlabel('Ptrans Existed')
plt.ylabel('Number of observations')
plt.show()

# %%
DataFrame
# Out:
#       Ptran     Prec       RSSI       PDR
# 0      -1.0 -67.9637 -1200.2879  1.000000
# 1      -1.0 -67.9637  -895.0007  1.000000
# 2      -1.0 -67.9637 -1200.2879  1.000000
# 3      -1.0 -88.5280  -874.4364  0.999432
# 4      -1.0 -66.3056  -992.4616  1.000000
# ...     ...      ...        ...       ...
# 6087    7.0 -79.0754  -647.7996  1.000000
# 6088    7.0 -80.4640 -1029.7147  1.000000
# 6089    7.0 -79.8773 -1193.2674  1.000000
# 6090    7.0 -81.8447 -1045.0763  0.999999
# 6091    7.0 -80.4640 -1028.1080  1.000000
#
# [6092 rows x 4 columns]

# %% [markdown]
# PHASE 3 - Split Dataset Into Features And Labels (For Every Model)

# %%
#For First Model 
features1 = DataFrame[['Ptran','Prec','RSSI']]
labels1 = DataFrame['PDR']

#For Second Model
features2 = DataFrame[['Prec','RSSI','PDR']]
labels2 = DataFrame['Ptran']

# %%
#Plot and describe the features dataset to understand them better

#First Model
sns.pairplot(features1[['Ptran', 'Prec', 'RSSI']], diag_kind='kde')

#Check some stats (std = The standard deviation is the average amount of variability in the dataset)
features1.describe().transpose()[['mean', 'std']]
# Out:
#              mean         std
# Ptran   -0.082896    4.292215
# Prec   -77.640682   12.753389
# RSSI  -933.253025  193.520664

# %%
#Plot and describe the features dataset to understand them better

#Second Model
sns.pairplot(features2[[ 'Prec', 'RSSI', 'PDR']], diag_kind='kde')

#Check some stats (std = The standard deviation is the average amount of variability in the dataset)
features2.describe().transpose()[['mean', 'std']]
# Out:
#             mean         std
# Prec  -77.640682   12.753389
# RSSI -933.253025  193.520664
# PDR     0.996543    0.017602

# %% [markdown]
# PHASE 4 - Train And Test Datasets (For Every Model)

# %%
# Split the data into train and test sets for first model
features_train1, features_test1, labels_train1, labels_test1 = train_test_split(features1, labels1, test_size=0.2, random_state=42)

# Split the data into train and test sets fro second model
features_train2, features_test2, labels_train2, labels_test2 = train_test_split(features2, labels2, test_size=0.2, random_state=42)

# %% [markdown]
# PHASE 5 - Scaling Using MinMax and Standard Scaler(For Every Model)

# %%
#First Model

# Scale the features using standard scaling
scaler1 = StandardScaler()
features_train = scaler1.fit_transform(features_train1)
features_test = scaler1.transform(features_test1)

# Scale the labels using MinMax scaling
label_scaler1 = MinMaxScaler()
labels = label_scaler1.fit_transform(labels1.values.reshape(-1, 1))

# %%
#Second Model

# Scale the features using standard scaling
scaler2 = StandardScaler()
features_train2 = scaler2.fit_transform(features_train2)
features_test2 = scaler2.transform(features_test2)

# Scale the labels using MinMax scaling
label_scaler2 = MinMaxScaler([-7,7])
labels2 = label_scaler2.fit_transform(labels2.values.reshape(-1, 1))

# %% [markdown]
# PHASE 6 - REGRESSION WITH NEURAL NETWORK

# %% [markdown]
# First approach --> Trying Ptran tiers(-7 to 7 with step = 1) and predict the expected PDR

# %%
# Define the first model architecture
model1 = Sequential()
model1.add(Dense(32, input_dim=features_train.shape[1], activation=keras.layers.LeakyReLU(alpha=0.01)))
model1.add(Dense(16, activation=keras.layers.LeakyReLU(alpha=0.01)))
model1.add(Dense(1))  # Linear activation function for regression

# Compile the model
model1.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
history1 =model1.fit(features_train, labels_train1, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 122/122 [==============================] - 1s 2ms/step - loss: 0.1431 - val_loss: 0.0286
# Epoch 2/5
# 122/122 [==============================] - 0s 1ms/step - loss: 0.0180 - val_loss: 0.0070
# Epoch 3/5
# 122/122 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0022
# Epoch 4/5
# 122/122 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 5/5
# 122/122 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 0.0011

# %%
# summarize history for loss for first model
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Evaluate loss for first  model
loss = model1.evaluate(features_test, labels_test1)
print(f'Test Loss: {loss}')
# Out:
# 39/39 [==============================] - 0s 809us/step - loss: 0.0013
# Test Loss: 0.001293668639846146

# %% [markdown]
# Second Approach --> Given an expected PDR calculate the desired Ptran

# %%
# Define the second model architecture
model2= Sequential()
model2.add(Dense(64, input_dim=features_train.shape[1], activation=keras.layers.LeakyReLU(alpha=0.01)))
model2.add(Dropout(0.2)) # Introducing Dropout Layers to enchance the performance
model2.add(Dense(32, activation=keras.layers.LeakyReLU(alpha=0.01)))
model2.add(Dropout(0.2))
model2.add(Dense(16, activation=keras.layers.LeakyReLU(alpha=0.01)))
model2.add(Dropout(0.2))
model2.add(Dense(1))  # Linear activation function for regression

# Compile the model
model2.compile(loss='mean_squared_error', optimizer='adam')

# Define  model checkpointing
model2_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True) #Introducing  Model Checkpoints  to enchance the performance

# Train the model
history2 = model2.fit(features_train, labels_train2, epochs=150, batch_size=32, validation_split=0.2, callbacks=[ model2_checkpoint])

# Load the best model
model2.load_weights('best_model.h5')
# Out:
# Epoch 1/150
# 122/122 [==============================] - 1s 2ms/step - loss: 10.5969 - val_loss: 0.5044
# Epoch 2/150
# 122/122 [==============================] - 0s 1ms/step - loss: 2.1510 - val_loss: 0.3454
# Epoch 3/150
# 122/122 [==============================] - 0s 2ms/step - loss: 1.7907 - val_loss: 0.1827
# Epoch 4/150
# 122/122 [==============================] - 0s 2ms/step - loss: 1.5782 - val_loss: 0.1581
# Epoch 5/150
# 122/122 [==============================] - 0s 1ms/step - loss: 1.3395 - val_loss: 0.1569
# Epoch 6/150
# 122/122 [==============================] - 0s 2ms/step - loss: 1.3029 - val_loss: 0.1673
# Epoch 7/150
# 122/122 [==============================] - 0s 1ms/step - loss: 1.2354 - val_loss: 0.0969
# Epoch 8/150
# 122/122 [==============================] - 0s 1ms/step - loss: 1.1512 - val_loss: 0.1629
# Epoch 9/150
# 122/122 [==============================] - 0s 1ms/step - loss: 1.1615 - val_loss: 0.1208
# Epoch 10/150
# 122/122 [==============================] - 0s 1ms/step - loss: 1.1034 - val_loss: 0.1779
# Epoch 11/150
# 122/122 [==============================] - 0s 1ms/step - loss: 1.0504 - val_loss: 0.1339
# Epoch 12/150
# 122/122 [==============================] - 0s 1ms/step - loss: 1.0013 - val_loss: 0.0945
# Epoch 13/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.9855 - val_loss: 0.0784
# Epoch 14/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.9977 - val_loss: 0.0495
# Epoch 15/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.9999 - val_loss: 0.0707
# Epoch 16/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.9752 - val_loss: 0.0573
# Epoch 17/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.9135 - val_loss: 0.0779
# Epoch 18/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.9047 - val_loss: 0.1782
# Epoch 19/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.9065 - val_loss: 0.0636
# Epoch 20/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.9027 - val_loss: 0.0646
# Epoch 21/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.9341 - val_loss: 0.1195
# Epoch 22/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.8341 - val_loss: 0.0417
# Epoch 23/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.8332 - val_loss: 0.0393
# Epoch 24/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.8191 - val_loss: 0.0593
# Epoch 25/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.7907 - val_loss: 0.0367
# Epoch 26/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.7751 - val_loss: 0.1037
# Epoch 27/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.8265 - val_loss: 0.0428
# Epoch 28/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.8096 - val_loss: 0.0258
# Epoch 29/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.7767 - val_loss: 0.0732
# Epoch 30/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.7916 - val_loss: 0.1259
# Epoch 31/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.7667 - val_loss: 0.0200
# Epoch 32/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.7727 - val_loss: 0.0232
# Epoch 33/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.7180 - val_loss: 0.0731
# Epoch 34/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.7014 - val_loss: 0.0780
# Epoch 35/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.7080 - val_loss: 0.0330
# Epoch 36/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.6746 - val_loss: 0.0406
# Epoch 37/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.7004 - val_loss: 0.0266
# Epoch 38/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.6624 - val_loss: 0.0255
# Epoch 39/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.6299 - val_loss: 0.0166
# Epoch 40/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.6334 - val_loss: 0.0425
# Epoch 41/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.6367 - val_loss: 0.0465
# Epoch 42/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.6145 - val_loss: 0.0410
# Epoch 43/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.6255 - val_loss: 0.0624
# Epoch 44/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.6124 - val_loss: 0.0680
# Epoch 45/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5809 - val_loss: 0.0700
# Epoch 46/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.6037 - val_loss: 0.0428
# Epoch 47/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5835 - val_loss: 0.0258
# Epoch 48/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5883 - val_loss: 0.0141
# Epoch 49/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5818 - val_loss: 0.0565
# Epoch 50/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5744 - val_loss: 0.0224
# Epoch 51/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5816 - val_loss: 0.0230
# Epoch 52/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5267 - val_loss: 0.0228
# Epoch 53/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5488 - val_loss: 0.0211
# Epoch 54/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5633 - val_loss: 0.0376
# Epoch 55/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5462 - val_loss: 0.0553
# Epoch 56/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5577 - val_loss: 0.0164
# Epoch 57/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5429 - val_loss: 0.0615
# Epoch 58/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5355 - val_loss: 0.0355
# Epoch 59/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5279 - val_loss: 0.0361
# Epoch 60/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5529 - val_loss: 0.0632
# Epoch 61/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5650 - val_loss: 0.0509
# Epoch 62/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5523 - val_loss: 0.0432
# Epoch 63/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5328 - val_loss: 0.0655
# Epoch 64/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5291 - val_loss: 0.0292
# Epoch 65/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5489 - val_loss: 0.0717
# Epoch 66/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5505 - val_loss: 0.0378
# Epoch 67/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5188 - val_loss: 0.0721
# Epoch 68/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5297 - val_loss: 0.1037
# Epoch 69/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5123 - val_loss: 0.0258
# Epoch 70/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5119 - val_loss: 0.0259
# Epoch 71/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5262 - val_loss: 0.0627
# Epoch 72/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4990 - val_loss: 0.1237
# Epoch 73/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5293 - val_loss: 0.0170
# Epoch 74/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5205 - val_loss: 0.0405
# Epoch 75/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5091 - val_loss: 0.0257
# Epoch 76/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4904 - val_loss: 0.0936
# Epoch 77/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4982 - val_loss: 0.0313
# Epoch 78/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5033 - val_loss: 0.0631
# Epoch 79/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5113 - val_loss: 0.0124
# Epoch 80/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5314 - val_loss: 0.0686
# Epoch 81/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5246 - val_loss: 0.0428
# Epoch 82/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5109 - val_loss: 0.0188
# Epoch 83/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5321 - val_loss: 0.0401
# Epoch 84/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5305 - val_loss: 0.0573
# Epoch 85/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5168 - val_loss: 0.0321
# Epoch 86/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5126 - val_loss: 0.0135
# Epoch 87/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5276 - val_loss: 0.0075
# Epoch 88/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5085 - val_loss: 0.0137
# Epoch 89/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5111 - val_loss: 0.0298
# Epoch 90/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4904 - val_loss: 0.0352
# Epoch 91/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5010 - val_loss: 0.0752
# Epoch 92/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5082 - val_loss: 0.0560
# Epoch 93/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4985 - val_loss: 0.0134
# Epoch 94/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.4940 - val_loss: 0.0166
# Epoch 95/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.4957 - val_loss: 0.0105
# Epoch 96/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5092 - val_loss: 0.0191
# Epoch 97/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.4887 - val_loss: 0.0647
# Epoch 98/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5015 - val_loss: 0.0077
# Epoch 99/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5015 - val_loss: 0.0588
# Epoch 100/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4983 - val_loss: 0.0311
# Epoch 101/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4894 - val_loss: 0.0541
# Epoch 102/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5208 - val_loss: 0.0204
# Epoch 103/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4897 - val_loss: 0.0401
# Epoch 104/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4883 - val_loss: 0.0677
# Epoch 105/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5067 - val_loss: 0.0344
# Epoch 106/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4920 - val_loss: 0.0412
# Epoch 107/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4797 - val_loss: 0.0315
# Epoch 108/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4960 - val_loss: 0.0092
# Epoch 109/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5136 - val_loss: 0.0250
# Epoch 110/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5192 - val_loss: 0.0255
# Epoch 111/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4876 - val_loss: 0.0080
# Epoch 112/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5093 - val_loss: 0.0134
# Epoch 113/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4944 - val_loss: 0.0581
# Epoch 114/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5049 - val_loss: 0.0721
# Epoch 115/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4982 - val_loss: 0.0649
# Epoch 116/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4716 - val_loss: 0.0160
# Epoch 117/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4869 - val_loss: 0.0389
# Epoch 118/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5028 - val_loss: 0.0547
# Epoch 119/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4903 - val_loss: 0.0651
# Epoch 120/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4969 - val_loss: 0.0113
# Epoch 121/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5015 - val_loss: 0.0144
# Epoch 122/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4865 - val_loss: 0.1000
# Epoch 123/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4810 - val_loss: 0.0140
# Epoch 124/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5113 - val_loss: 0.0452
# Epoch 125/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5030 - val_loss: 0.0264
# Epoch 126/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4683 - val_loss: 0.0144
# Epoch 127/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5071 - val_loss: 0.0234
# Epoch 128/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5001 - val_loss: 0.0556
# Epoch 129/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.5093 - val_loss: 0.0351
# Epoch 130/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5235 - val_loss: 0.0066
# Epoch 131/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4474 - val_loss: 0.0505
# Epoch 132/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4794 - val_loss: 0.0148
# Epoch 133/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4848 - val_loss: 0.0444
# Epoch 134/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4717 - val_loss: 0.0112
# Epoch 135/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4653 - val_loss: 0.1300
# Epoch 136/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4942 - val_loss: 0.0320
# Epoch 137/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4624 - val_loss: 0.0419
# Epoch 138/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4846 - val_loss: 0.0511
# Epoch 139/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5047 - val_loss: 0.0434
# Epoch 140/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4683 - val_loss: 0.0216
# Epoch 141/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4775 - val_loss: 0.0226
# Epoch 142/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4659 - val_loss: 0.0334
# Epoch 143/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4755 - val_loss: 0.0274
# Epoch 144/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4697 - val_loss: 0.0328
# Epoch 145/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4943 - val_loss: 0.0493
# Epoch 146/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4897 - val_loss: 0.0515
# Epoch 147/150
# 122/122 [==============================] - 0s 2ms/step - loss: 0.4837 - val_loss: 0.0177
# Epoch 148/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4390 - val_loss: 0.0406
# Epoch 149/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4630 - val_loss: 0.0096
# Epoch 150/150
# 122/122 [==============================] - 0s 1ms/step - loss: 0.4614 - val_loss: 0.0111

# %%
# summarize history for loss for second model
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# PHASE 7 - Make Predictions(For Every Model)

# %% [markdown]
# For First Model

# %%
# Make predictions on test feautures
predictions1 = model1.predict(features_test)

#Change 2D array to 1D array to perform the inverse_transform
labels_test1 = labels_test1.values.reshape(-1, 1)
predictions1 = predictions1.reshape(-1, 1)

# Inverse scale the predictions and the labels_test for plotting
labels_test1 = label_scaler1.inverse_transform(labels_test1)
predictions1 = label_scaler1.inverse_transform(predictions1)

# Scatter plot of actual vs. predicted
plt.figure(figsize=(10, 6))

# Scatter plot of actual values, in red
plt.scatter(range(len(labels_test1)), labels_test1, color='red', label='Actual')

# Scatter plot of predicted values, in blue
plt.scatter(range(len(predictions1)), predictions1, color='blue', alpha=0.5, label='Predicted')

plt.title('Actual vs Predicted PDR')
plt.xlabel('Index')
plt.ylabel('PDR')
plt.legend()
plt.show()
# Out:
# 39/39 [==============================] - 0s 649us/step

# %% [markdown]
# For Second Model

# %%
# Generate predictions on test data
predictions2 = model2.predict(features_test2)

#Change 2D array to 1D array to perform the inverse_transform
#labels_test2 = labels_test2.values.reshape(-1, 1)
#predictions2 = predictions2.reshape(-1, 1)

# Inverse scale the predictions and the labels_test for plotting
#labels_test2 = label_scaler2.inverse_transform(labels_test2)
#predictions2 = label_scaler2.inverse_transform(predictions2)


# Scatter plot of actual vs. predicted
plt.figure(figsize=(10, 6))
plt.scatter(range(len(labels_test2)), labels_test2, color='red', label='Actual')
plt.scatter(range(len(predictions2)), predictions2, color='blue', alpha=0.5, label='Predicted')
plt.title('Actual vs Predicted Ptran')
plt.xlabel('Index')
plt.ylabel('Ptran')
plt.legend()
plt.show()
# Out:
# 39/39 [==============================] - 0s 709us/step

# %% [markdown]
# PHASE 8 - Perform Single Datapoints Predictions For Every Model (For Testing Purpose)

# %% [markdown]
# Example --> First Record =  "Ptran": [-1], "Prec": [-67.9637], "RSSI": [-1200.2879], "PDR": [1.000000]

# %%
#For First Model
# Change the feautures values(Ptran,Prec,RSSI) and see the predicted label(PDR):
test_data_1 = pd.DataFrame({"Ptran": [-1], "Prec": [-67.9637], "RSSI": [-1200.2879]})

# Scale the data
test_data_scaled_1 = scaler1.transform(test_data_1)

# Predict the PDR using the model
prediction_test_1 = model1.predict(test_data_scaled_1)

# Rescale the prediction back to the original scale
test_prediction_1 = label_scaler1.inverse_transform(prediction_test_1)

#Print the one-data-point prediction
test_prediction_1
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([[0.9998915]], dtype=float32)

# %%
#For Second Model example: exp:-67.9637	-1200.2879	1.000000
# Change the feautures values(Prec,RSSI,PDR) and see the predicted label(Ptran):
test_data_2 = pd.DataFrame({"Prec": [-67.9637], "RSSI": [-1200.2879], "PDR": [1.000000]})

# Scale the data
test_data_scaled_2 = scaler2.transform(test_data_2)

## Predict the PDR using the model
prediction_test_2 = model2.predict(test_data_scaled_2)

#Rescale the prediction back to the original scale
test_prediction_2 = label_scaler2.inverse_transform(prediction_test_2)

#Print the one-data-point prediction
test_prediction_2
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[3.3532312]], dtype=float32)

# %% [markdown]
# PHASE 9 - Evaluate Models Using R^2 Score

# %%
# For the first model

# Calculate R^2 score
r2_1 = r2_score(labels_test1, predictions1)
print(f'R^2 score: {r2_1}')
# Out:
# R^2 score: -2.4488014749661806

# %%
# For the Second model

# Calculate R^2 score
r2_2 = r2_score(labels_test2, predictions2)
print(f'R^2 score: {r2_2}')
# Out:
# R^2 score: -1.3159056162988678

# %% [markdown]
# PHASE 10 - Evaluate Models Using  Mean Absolute Error, Mean Squared Error, Root Mean Squared Error

# %%
# Calculate the errors for first model
mae1 = mean_absolute_error(labels_test1, predictions1)
mse1 = mean_squared_error(labels_test1, predictions1)
rmse1 = np.sqrt(mse1)

print(f"Mean Absolute Error: {mae1}")
print(f"Mean Squared Error: {mse1}")
print(f"Root Mean Squared Error: {rmse1}")
# Out:
# Mean Absolute Error: 0.0067646327650631825
# Mean Squared Error: 0.00012134809571202615
# Root Mean Squared Error: 0.01101581116904362

# %%
# Calculate the errors
mae2 = mean_absolute_error(labels_test2, predictions2)
mse2 = mean_squared_error(labels_test2, predictions2)
rmse2 = np.sqrt(mse2)

print(f"Mean Absolute Error: {mae2}")
print(f"Mean Squared Error: {mse2}")
print(f"Root Mean Squared Error: {rmse2}")
# Out:
# Mean Absolute Error: 5.271561640014504
# Mean Squared Error: 42.41495150154359
# Root Mean Squared Error: 6.512676216544439

# %% [markdown]
# Build In Library -- RandomForestRegressor

# %% [markdown]
# Ptran PREDITCTION

# %%
#Import Needed Libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# Copy the dataframe
df3 = DataFrame.copy()
df3
# Out:
#       Ptran     Prec       RSSI       PDR
# 0      -1.0 -67.9637 -1200.2879  1.000000
# 1      -1.0 -67.9637  -895.0007  1.000000
# 2      -1.0 -67.9637 -1200.2879  1.000000
# 3      -1.0 -88.5280  -874.4364  0.999432
# 4      -1.0 -66.3056  -992.4616  1.000000
# ...     ...      ...        ...       ...
# 6087    7.0 -79.0754  -647.7996  1.000000
# 6088    7.0 -80.4640 -1029.7147  1.000000
# 6089    7.0 -79.8773 -1193.2674  1.000000
# 6090    7.0 -81.8447 -1045.0763  0.999999
# 6091    7.0 -80.4640 -1028.1080  1.000000
#
# [6092 rows x 4 columns]

# %%
# Selecting features and labels
features3 = df3[["Prec", "RSSI", "PDR"]]
labels3 = df3["Ptran"]

# %%
# Splitting the data into training and test sets
features_train3, features_test3, labels_train3, labels_test3 = train_test_split(features3, labels3, test_size=0.2, random_state=42)

# %%
# Initialize Random Forest model
model3 = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model
model3.fit(features_train3, labels_train3)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Make predictions
predictions3 = model3.predict(features_test3)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(labels_test3, predictions3))
print("RMSE: %f" % (rmse))

# Plot Predicted vs Actual
plt.figure(figsize=(12, 6))
plt.scatter(predictions3, labels_test3, alpha=0.2, color='red', label='Predicted')
plt.scatter(labels_test3, labels_test3, alpha=0.2, color='blue', label='Actual')
plt.title('Predicted vs Actual')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.legend()
plt.show()
# Out:
# RMSE: 0.792601

# %%
from sklearn.metrics import r2_score

# Calculate R-squared score
r2_3 = r2_score(labels_test3, predictions3)
print("R-squared Score: %f" % (r2_3))
# Out:
# R-squared Score: 0.965699

# %%
# Single data point: 
# Example --> First Record =  "Ptran": [-1], "Prec": [-67.9637], "RSSI": [-1200.2879], "PDR": [1.000000]

single_data_point3 = [[-79.0754, -1200.7996,1.000000]]  # Format: [Prec, RSSI, PDR]

#Convert into numpy array
single_data_point3 = np.array(single_data_point3)

# Use the model to make a prediction
single_point_prediction3 = model3.predict(single_data_point3)

print("Predicted Ptran for the given data point: ", single_point_prediction3)
# Out:
# Predicted Ptran for the given data point:  [-0.66]
# c:\Users\30698\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# PDR PREDICTION

# %%
#Copy Dataframe
df4 = DataFrame.copy()
df4
# Out:
#       Ptran     Prec       RSSI       PDR
# 0      -1.0 -67.9637 -1200.2879  1.000000
# 1      -1.0 -67.9637  -895.0007  1.000000
# 2      -1.0 -67.9637 -1200.2879  1.000000
# 3      -1.0 -88.5280  -874.4364  0.999432
# 4      -1.0 -66.3056  -992.4616  1.000000
# ...     ...      ...        ...       ...
# 6087    7.0 -79.0754  -647.7996  1.000000
# 6088    7.0 -80.4640 -1029.7147  1.000000
# 6089    7.0 -79.8773 -1193.2674  1.000000
# 6090    7.0 -81.8447 -1045.0763  0.999999
# 6091    7.0 -80.4640 -1028.1080  1.000000
#
# [6092 rows x 4 columns]

# %%
# Selecting features and labels
features4 = df4[["Ptran", "Prec", "RSSI"]]
labels4 = df4["PDR"]

# %%
# Splitting the data into training and test sets
features_train4, features_test4, labels_train4, labels_test4 = train_test_split(features4, labels4, test_size=0.2, random_state=42)

# %%
# Initialize First Random Forest model
model4 = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model
model4.fit(features_train4, labels_train4)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Make predictions
predictions4 = model4.predict(features_test4)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(labels_test4, predictions4))
print("RMSE: %f" % (rmse))

# Plot Predicted vs Actual
plt.figure(figsize=(12, 6))
plt.scatter(predictions4, labels_test4, alpha=0.2, color='red', label='Predicted')
plt.scatter(labels_test4, labels_test4, alpha=0.2, color='blue', label='Actual')
plt.title('Predicted vs Actual')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.legend()
plt.show()
# Out:
# RMSE: 0.000378

# %%
from sklearn.metrics import r2_score

# Calculate R-squared score
r2_4 = r2_score(labels_test4, predictions4)
print("R-squared Score: %f" % (r2_4))
# Out:
# R-squared Score: 0.999618

# %%
# Single data point: 
# Example --> First Record =  "Ptran": [-1], "Prec": [-67.9637], "RSSI": [-1200.2879], "PDR": [1.000000]	
single_data_point4 = [[-1.0, -67.9637, -1200.2879]]  # Format: [Ptran, Prec, RSSI]

# Ensure the single_data_point is a numpy array
single_data_point4 = np.array(single_data_point4)

# Use the model to predict
single_point_prediction4 = model4.predict(single_data_point4)

print("Predicted PDR for the given data point: ", single_point_prediction4)
# Out:
# Predicted PDR for the given data point:  [0.99999999]
# c:\Users\30698\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
